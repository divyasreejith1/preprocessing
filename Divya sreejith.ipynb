# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Load the dataset into python environment

# %%
data=pd.read_csv(r'C:\Users\sreej\Downloads\titanic_dataset.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
data.set_index('PassengerId',inplace=True)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # 3. Check the basic details of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data.dropna(subset=['Embarked'],how='any',inplace=True)

# %%
data['Cabin']=data['Cabin'].fillna('Unknown')

# %%
data['Age']=data['Age'].fillna(data['Age'].median())

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %% [markdown]
# # Check and handle outliers in at least 3 columns in the dataset

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.382452    2.311586   29.315152    0.524184    0.382452   32.096681
# std      0.486260    0.834700   12.984932    1.103705    0.806761   49.697504
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
#Checking the outliers of Fare column

# %%
plt.boxplot(data['Fare'])
plt.title('Boxplot of Fare')
plt.show()

# %%
Q1=np.percentile(data['Fare'],25,interpolation='midpoint')
Q2=np.percentile(data['Fare'],50,interpolation='midpoint')
Q3=np.percentile(data['Fare'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 7.8958
# 14.4542
# 31.0

# %%
IQR=Q3-Q1

# %%
print(IQR)
# Out:
# 23.1042

# %%
low_limit=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(low_limit)
print(up_limit)
# Out:
# -26.7605
# 65.6563

# %%
outlier=[]
for x in data['Fare']:
 if((x >up_limit) or (x< low_limit)):
    outlier.append(x)

# %%
#outliers of column'Fare'

# %%
outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
# ...

# %%
data.loc[data['Fare']>up_limit].index
# Out:
# Int64Index([  2,  28,  32,  35,  53,  63,  73,  89, 103, 119,
#             ...
#             790, 793, 803, 821, 836, 847, 850, 857, 864, 880],
#            dtype='int64', name='PassengerId', length=114)

# %%
#Dropping outliers of column 'Fare'

# %%
data1=data.drop(data.loc[data['Fare']>up_limit].index)

# %%
data1
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
#checking the outliers of SibSp

# %%
plt.boxplot(data1['SibSp'])
plt.title('Boxplot of SibSp')
plt.show()

# %%
Q1=np.percentile(data1['SibSp'],25,interpolation='midpoint')
Q2=np.percentile(data1['SibSp'],50,interpolation='midpoint')
Q3=np.percentile(data1['SibSp'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 0.0
# 0.0
# 1.0

# %%
IQR=Q3-Q1

# %%
print(IQR)
# Out:
# 1.0

# %%
low_limit=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(low_limit)
print(up_limit)
# Out:
# -1.5
# 2.5

# %%
outlier=[]
for x in data1['SibSp']:
 if((x >up_limit) or (x< low_limit)):
    outlier.append(x)

# %%
#outliers of SibSp

# %%
outlier
# Out:
# [3,
#  4,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  4,
#  4,
#  4,
#  3,
#  4,
#  3,
#  4,
#  4,
#  4,
#  4,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  4,
#  3,
#  4,
#  4]

# %%
data1.loc[data1['SibSp']>up_limit].index
# Out:
# Int64Index([  8,  17,  25,  51,  60,  64,  69,  72,  86, 120, 165, 172, 177,
#             183, 230, 234, 262, 267, 279, 375, 387, 410, 481, 486, 542, 543,
#             635, 643, 684, 687, 727, 788, 814, 820, 825, 851],
#            dtype='int64', name='PassengerId')

# %%
#dropping the outliers of SibSp

# %%
data2=data1.drop(data1.loc[data1['SibSp']>up_limit].index)

# %%
data2.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  739.000000  739.000000  739.000000  739.000000  739.000000  739.000000
# mean     0.349120    2.456022   29.620095    0.274696    0.286874   17.172772
# std      0.477015    0.742917   12.278717    0.506378    0.753657   13.425327
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   23.000000    0.000000    0.000000    7.891650
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   11.500000
# 75%      1.000000    3.000000   34.250000    0.000000    0.000000   25.929200
# max      1.000000    3.000000   80.000000    2.000000    6.000000   65.000000

# %%
data2
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
#checking the outliers of Age

# %%
plt.boxplot(data2['Age'])
plt.title('Boxplot of Age')
plt.show()

# %%
Q1=np.percentile(data2['Age'],25,interpolation='midpoint')
Q2=np.percentile(data2['Age'],50,interpolation='midpoint')
Q3=np.percentile(data2['Age'],75,interpolation='midpoint')

# %%
print(Q1)
print(Q2)
print(Q3)
# Out:
# 23.0
# 28.0
# 34.25

# %%
IQR=Q3-Q1

# %%
print(IQR)
# Out:
# 11.25

# %%
low_limit=Q1-1.5*IQR
up_limit=Q3+1.5*IQR

# %%
print(low_limit)
print(up_limit)
# Out:
# 6.125
# 51.125

# %%
outlier=[]
for x in data2['Age']:
 if((x >up_limit) or (x< low_limit)):
    outlier.append(x)

# %%
outlier
# Out:
# [54.0,
#  4.0,
#  58.0,
#  55.0,
#  66.0,
#  3.0,
#  65.0,
#  5.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  55.5,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  4.0,
#  3.0,
#  2.0,
#  59.0,
#  54.0,
#  62.0,
#  65.0,
#  54.0,
#  61.0,
#  2.0,
#  3.0,
#  1.0,
#  3.0,
#  5.0,
#  52.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  54.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  53.0,
#  54.0,
#  4.0,
#  61.0,
#  57.0,
#  80.0,
#  0.75,
#  56.0,
#  70.0,
#  60.0,
#  4.0,
#  60.0,
#  52.0,
#  52.0,
#  6.0,
#  4.0,
#  6.0,
#  0.67,
#  57.0,
#  54.0,
#  5.0,
#  1.0,
#  0.42,
#  1.0,
#  0.83,
#  74.0,
#  4.0]

# %%
data2.loc[data2['Age']>up_limit].index
# Out:
# Int64Index([  7,  12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 233, 250,
#             253, 281, 318, 327, 450, 457, 468, 484, 488, 493, 494, 514, 546,
#             556, 571, 572, 583, 626, 627, 631, 648, 673, 685, 695, 696, 715,
#             773, 775, 852],
#            dtype='int64', name='PassengerId')

# %%
#dropping the column 'Age'

# %%
data3=data2.drop(data2.loc[data2['Age']>up_limit].index)

# %%
data3
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
#After checking and dropping the outliers of columns['Age','SibSp','Fare']

# %%
data3
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %%
data3.shape
# Out:
# (697, 11)

# %% [markdown]
# # Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_enc=LabelEncoder()

# %%
data['Sex']=label_enc.fit_transform(data['Sex'])

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
#
#              SibSp  Parch            Ticket     Fare    Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500  Unknown        S
# 2                1      0          PC 17599  71.2833      C85        C
# 3                0      0  STON/O2. 3101282   7.9250  Unknown        S
# ...

# %%
data['Embarked']=label_enc.fit_transform(data['Embarked'])

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0
# 3                                       Heikkinen, Miss. Laina    0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0
# 5                                     Allen, Mr. William Henry    1  35.0
#
#              SibSp  Parch            Ticket     Fare    Cabin  Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500  Unknown         2
# 2                1      0          PC 17599  71.2833      C85         0
# 3                0      0  STON/O2. 3101282   7.9250  Unknown         2
# ...

# %%
data=data.drop(['Name','Cabin','Ticket'],axis=1)

# %%
data.head()
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# PassengerId
# 1                   0       3    1  22.0      1      0   7.2500         2
# 2                   1       1    0  38.0      1      0  71.2833         0
# 3                   1       3    0  26.0      0      0   7.9250         2
# 4                   1       1    0  35.0      1      0  53.1000         2
# 5                   0       3    1  35.0      0      0   8.0500         2

# %%
data.shape
# Out:
# (889, 8)

# %%
X=data.drop('Survived',axis=1)
Y=data['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 42, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
model=lr.fit(X_train,Y_train)
predctions=model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
print('Mean Squared Error is:',mean_squared_error(Y_test,predctions))
print('R Squared is',r2_score(Y_test,predctions))
# Out:
# Mean Squared Error is: 0.19157330334074438
# R Squared is 0.20485810095747514

# %% [markdown]
# # min max scaling

# %%
X.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  889.000000  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     2.311586    0.649044   29.315152    0.524184    0.382452   32.096681
# std      0.834700    0.477538   12.984932    1.103705    0.806761   49.697504
# min      1.000000    0.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000   22.000000    0.000000    0.000000    7.895800
# 50%      3.000000    1.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000    1.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000    1.000000   80.000000    8.000000    6.000000  512.329200
#
#          Embarked
# count  889.000000
# mean     1.535433
# std      0.792088
# min      0.000000
# 25%      1.000000
# 50%      2.000000
# 75%      2.000000
# max      2.000000

# %%
#dropping of the categorical columns 'Sex' and 'Embarked'

# %%
X1=X.drop(['Sex','Embarked'],axis=1)

# %%
X1.head()
# Out:
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.0      1      0   7.2500
# 2                 1  38.0      1      0  71.2833
# 3                 3  26.0      0      0   7.9250
# 4                 1  35.0      1      0  53.1000
# 5                 3  35.0      0      0   8.0500

# %%
#importing min max scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler=MinMaxScaler(feature_range=(0,1))

# %%
X1=min_max_scaler.fit_transform(X1)

# %%
type(X1)
# Out:
# numpy.ndarray

# %%
X1=pd.DataFrame(X1,columns=['Pclass', 'Age', 'SibSp', 'Parch', 'Fare'])

# %%
type(X1)
# Out:
# pandas.core.frame.DataFrame

# %%
X1.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  889.000000  889.000000  889.000000  889.000000  889.000000
# mean     0.655793    0.363096    0.065523    0.063742    0.062649
# std      0.417350    0.163168    0.137963    0.134460    0.097003
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.271174    0.000000    0.000000    0.015412
# 50%      1.000000    0.346569    0.000000    0.000000    0.028213
# 75%      1.000000    0.434531    0.125000    0.000000    0.060508
# max      1.000000    1.000000    1.000000    1.000000    1.000000

# %%
X1.shape
# Out:
# (889, 5)
